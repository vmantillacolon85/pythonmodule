# %%
conda install pandasql

# %%
import pandas as pd

# %%
df_NYC_pop = pd.read_json('data/NYCPopulation.json')

# %%
df = pd.read_csv('data/pizza_with_borough.csv')

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

print(pysqldf("""Select * FROM df
              JOIN df_NYC_pop on df.borough=df_NYC_pop.borough """))
# Out:
#                                               Name  location_lat  \
# 0                                    Angelos Pizza     40.623254
# 1                                   Ozone Pizzeria     40.680892
# 2                                       Pino Pizza     40.600015
# 3                                       La Rondine     40.713335
# 4                               Rony's Fresh Pizza     40.748251
# ..                                             ...           ...
# 412                          Bleecker Street Pizza     40.732267
# 413                          Chai Pizza Sushi Cafe     40.697700
# 414  Alphonso's Pizzeria & Trattoria - Pizza Shack     40.714338
# 415                                  Frank's Pizza     40.617720
# 416                                     Bona Pizza     40.640977
#
#      location_lng       Date Date Expanded (times in EST)  Year  \
# 0      -73.937922  2022-1014    Oct 14th 2022, 5:57:51 pm  2022
# ...

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

joined_df=pysqldf("""Select * FROM df
              JOIN df_NYC_pop on df.borough=df_NYC_pop.borough """)

# %%
## joined_df = df.join(df_NYC_pop.set_index('borough'), on='borough', how = 'inner') this is the way to do it in just plain pandas/python not pandasql.

# %%
joined_df
# Out:
#                                      Name  location_lat  location_lng  \
# 0                           Angelos Pizza     40.623254    -73.937922
# 2                              Pino Pizza     40.600015    -73.999455
# 7                             N & D Pizza     40.600463    -73.943072
# 17                           Jojo's Pizza     40.655045    -73.916051
# 21                       On The Run Pizza     40.576870    -73.984621
# ..                                    ...           ...           ...
# 273                     Tony's Original's     40.638290    -74.079380
# 336                     Nunzio's Pizzeria     40.577940    -74.102590
# 382                          Crispy Pizza     40.644571    -74.098385
# 409  Domenico's Pizza & Pasta, Amboy Road     40.525698    -74.201928
# 419                          Pronto Pizza     40.640550    -74.116110
#
#           Date Date Expanded (times in EST)  Year  Price as number   Price  \
# ...

# %%
conda install psycopg2
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/vmcolon/opt/anaconda3
#
#   added / updated specs:
#     - psycopg2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     psycopg2-2.9.3             |   py39h0a4fc7d_0         143 KB
#     ------------------------------------------------------------
#                                            Total:         143 KB
#
# The following NEW packages will be INSTALLED:
#
#   psycopg2           pkgs/main/osx-64::psycopg2-2.9.3-py39h0a4fc7d_0
#
#
#
# ...
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
import pandas as pd
import psycopg2

engine = create_engine('postgresql+psycopg2://analyst:moonbase2@database-test.cxtidmp4j8wi.us-east-2.rds.amazonaws.com:5432/northwind')

table_df = pd.read_sql("""
WITH all_revenue AS
(
SELECT c.company_name, c.country,
sum(od.unit_price*od.quantity*(1-od.discount)) AS customer_revenue
FROM customers c
LEFT JOIN orders o
ON o.customer_id = c.customer_id
JOIN order_details od
ON od.order_id = o.order_id
GROUP BY c.company_name, c.country
)
SELECT company_name, country, customer_revenue,
sum(customer_revenue) OVER (PARTITION BY country) AS total_country_revenue
FROM all_revenue
ORDER BY total_country_revenue DESC, country""",
    con=engine
                      )

# %%
table_df.head()
# Out:
#                  company_name country  customer_revenue  total_country_revenue
# 0  Rattlesnake Canyon Grocery     USA      51097.800828          245584.610302
# 1       Split Rail Beer & Ale     USA      11441.630072          245584.610302
# 2        Lazy K Kountry Store     USA        356.999998          245584.610302
# 3              The Big Cheese     USA       3361.000004          245584.610302
# 4  Hungry Coyote Import Store     USA       3063.200025          245584.610302

# %%
table_df['market_share']=table_df['customer_revenue']/table_df['total_country_revenue']

# %%
table_df['market_share'] = 0

# %%
table_df.drop(columns = 'market_share')
# Out:
#                   company_name    country  customer_revenue  \
# 0   Rattlesnake Canyon Grocery        USA      51097.800828
# 1        Split Rail Beer & Ale        USA      11441.630072
# 2         Lazy K Kountry Store        USA        356.999998
# 3               The Big Cheese        USA       3361.000004
# 4   Hungry Coyote Import Store        USA       3063.200025
# ..                         ...        ...               ...
# 84      Océano Atlántico Ltda.  Argentina       3460.200008
# 85               Rancho grande  Argentina       2844.099998
# 86  Cactus Comidas para llevar  Argentina       1814.799984
# 87               Santé Gourmet     Norway       5735.150015
# 88              Wolski  Zajazd     Poland       3531.949996
#
#     total_country_revenue  market share      continent  empty
# 0           245584.610302      0.208066  North America      0
# 1           245584.610302      0.046589  North America      0
# ...

# %%
table_df['country'].unique()
# Out:
# array(['USA', 'Germany', 'Austria', 'Brazil', 'France', 'UK', 'Venezuela',
#        'Sweden', 'Canada', 'Ireland', 'Belgium', 'Denmark', 'Switzerland',
#        'Mexico', 'Finland', 'Spain', 'Italy', 'Portugal', 'Argentina',
#        'Norway', 'Poland'], dtype=object)

# %%
continent_map= {
    'USA': 'North America',
    'Canada': 'North America',
    'Germany': 'Europe'
}
table_df['continent']=table_df['country'].map(continent_map)

# %%
table_df.head()
# Out:
#                  company_name country  customer_revenue  \
# 0  Rattlesnake Canyon Grocery     USA      51097.800828
# 1       Split Rail Beer & Ale     USA      11441.630072
# 2        Lazy K Kountry Store     USA        356.999998
# 3              The Big Cheese     USA       3361.000004
# 4  Hungry Coyote Import Store     USA       3063.200025
#
#    total_country_revenue  market share  market_share      continent  empty
# 0          245584.610302      0.208066             0  North America      0
# 1          245584.610302      0.046589             0  North America      0
# 2          245584.610302      0.001454             0  North America      0
# 3          245584.610302      0.013686             0  North America      0
# 4          245584.610302      0.012473             0  North America      0

# %%
table_df.describe()
# Out:
#            order_id         total
# count    830.000000    830.000000
# mean   10662.500000   1631.877820
# std      239.744656   1990.613969
# min    10248.000000     12.500000
# 25%    10455.250000    480.000002
# 50%    10662.500000   1015.900009
# 75%    10869.750000   2028.649990
# max    11077.000000  17250.000000
